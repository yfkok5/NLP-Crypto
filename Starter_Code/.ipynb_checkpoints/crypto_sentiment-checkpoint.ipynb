# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from newsapi import NewsApiClient
analyzer = SentimentIntensityAnalyzer()
from nltk.tokenize import word_tokenize

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\yfkok\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv()
api_key = os.getenv("NEWS_API_KEY")

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
btc_news = newsapi.get_everything(q = "bitcoin AND BTC AND 2022",language="en")
btc_news["totalResults"]
# Out:
# 1266

# %%
# Fetch the Ethereum news articles
eth_news = newsapi.get_everything(q = "ethereum AND ETH AND 2022",language="en")
eth_news["totalResults"]
# Out:
# 772

# %%
# Create the Bitcoin sentiment scores DataFrame
btc_sentiments = []

for article in btc_news["articles"]:
    
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        btc_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
btc_df = pd.DataFrame(btc_sentiments)

# %%
# Create the Ethereum sentiment scores DataFrame
eth_sentiments = []

for article in eth_news["articles"]:
    
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        eth_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
    
eth_df = pd.DataFrame(eth_sentiments)

# %%
# Describe the Bitcoin Sentiment
btc_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.043520   0.057500   0.042000   0.900550
# std     0.341464   0.051405   0.063622   0.097133
# min    -0.542300   0.000000   0.000000   0.614000
# 25%    -0.081300   0.000000   0.000000   0.851000
# 50%     0.051350   0.069500   0.000000   0.918000
# 75%     0.264275   0.085000   0.062750   0.966250
# max     0.709600   0.169000   0.217000   1.000000

# %%
# Describe the Ethereum Sentiment
eth_df.describe()
# Out:
#         compound   positive  negative    neutral
# count  20.000000  20.000000  20.00000  20.000000
# mean    0.167930   0.073700   0.03395   0.892350
# std     0.394712   0.073036   0.03575   0.069703
# min    -0.542300   0.000000   0.00000   0.737000
# 25%    -0.115300   0.000000   0.00000   0.857750
# 50%     0.249150   0.064500   0.03800   0.890500
# 75%     0.505750   0.135000   0.05600   0.945500
# max     0.865500   0.263000   0.11300   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum (0.0737 vs 0.0575)
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum (0.8655 vs 0.7096)
#
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum (0.263 vs 0.169)

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = set(stopwords.words('english'))

# Expand the default stopwords list if necessary
sw_addons = {'said', 'sent', 'found', 'including', 'today', 'announced', 'week', 'basically', 'also'}

# %%
# Complete the tokenizer function
def clean_text(article):
    
    # Create a list of the words
    sw = set(stopwords.words('english'))

    # Convert the words to lowercase
    regex = re.compile("[^a-zA-Z ]")

    # Remove the punctuation
    re_clean = regex.sub('', article)

    # Remove the stop words
    words = word_tokenize(re_clean)

    # Lemmatize Words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
    # .union combines all items from two sets (AND EXCLUDES DUPLICATES)
    output = [word.lower() for word in lem if word.lower() not in sw.union(sw_addons)]
    
    # Return the final list
    return output

# %%
# Create a new tokens column for Bitcoin
btc_df['tokens'] = btc_df['text'].apply(word_tokenize)
btc_df.head()
# Out:
#                                                 text        date  compound  \
# 0  <ul><li>Elon Musk will be able to focus on Tes...  2022-04-19    0.4404
# 1  Apparently not satisfied to report that it had...  2022-04-13   -0.3252
# 2  Financial markets are in a rough patch, as the...  2022-05-07   -0.4215
# 3  Bitcoin's ( BTC 0.37% ) monumental run through...  2022-04-09    0.3071
# 4  What happened\r\nShares of Riot Blockchain(RIO...  2022-05-06   -0.4939
#
#    positive  negative  neutral  \
# 0     0.079     0.000    0.921
# 1     0.000     0.061    0.939
# 2     0.082     0.158    0.761
# 3     0.085     0.000    0.915
# 4     0.169     0.217    0.614
#
#                                               tokens
# 0  [<, ul, >, <, li, >, Elon, Musk, will, be, abl...
# 1  [Apparently, not, satisfied, to, report, that,...
# 2  [Financial, markets, are, in, a, rough, patch,...
# 3  [Bitcoin, 's, (, BTC, 0.37, %, ), monumental, ...
# 4  [What, happened, Shares, of, Riot, Blockchain,...

# %%
# Create a new tokens column for Ethereum
eth_df['tokens'] = eth_df['text'].apply(word_tokenize)
eth_df.head()
# Out:
#                                                 text        date  compound  \
# 0  A multi-billion dollar cryptocurrency company ...  2022-05-02   -0.2263
# 1  When Bored Ape Yacht Club creators Yuga Labs a...  2022-05-04   -0.2732
# 2  If you ever wanted to buy an NFT based on Ethe...  2022-05-02   -0.1027
# 3  Digital transformation is disrupting global bu...  2022-04-18    0.4939
# 4  Mike Masnick wrote a good piece on this topic ...  2022-04-10    0.5413
#
#    positive  negative  neutral  \
# 0     0.046     0.075    0.879
# 1     0.000     0.055    0.945
# 2     0.000     0.036    0.964
# 3     0.135     0.000    0.865
# 4     0.143     0.055    0.802
#
#                                               tokens
# 0  [A, multi-billion, dollar, cryptocurrency, com...
# 1  [When, Bored, Ape, Yacht, Club, creators, Yuga...
# 2  [If, you, ever, wanted, to, buy, an, NFT, base...
# 3  [Digital, transformation, is, disrupting, glob...
# 4  [Mike, Masnick, wrote, a, good, piece, on, thi...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2

def word_counter(corpus): 
    # Combine all articles in corpus into one large string
    big_string = ' '.join(corpus.text)
    processed = clean_text(big_string)
    bigrams = ngrams(processed, n=2)
    top_10 = dict(Counter(bigrams).most_common(10))
    return pd.DataFrame(list(top_10.items()), columns=['bigram', 'count'])

word_counter(btc_df)
# Out:
#                      bigram  count
# 0          (interest, rate)      4
# 1            (bitcoin, btc)      3
# 2            (market, char)      2
# 3      (rate, geopolitical)      2
# 4  (cryptocurrency, market)      2
# 5       (federal, reserves)      2
# 6          (rate, decision)      2
# 7              (char, good)      2
# 8           (good, morning)      2
# 9         (omaha, nebraska)      2

# %%
# Generate the Ethereum N-grams where N=2
word_counter(eth_df)
# Out:
#                      bigram  count
# 0           (ethereum, eth)      3
# 1              (bored, ape)      2
# 2              (ape, yacht)      2
# 3             (yacht, club)      2
# 4              (yuga, labs)      2
# 5                (ha, char)      2
# 6                 (eth, ha)      2
# 7      (nonfungible, token)      2
# 8    (multibillion, dollar)      1
# 9  (dollar, cryptocurrency)      1

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=10):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin

btc_text = ' '.join(btc_df.text)
btc_processed = clean_text(btc_text)

token_count(btc_processed)
# Out:
# [('char', 20),
#  ('bitcoin', 9),
#  ('market', 6),
#  ('april', 6),
#  ('btc', 5),
#  ('rate', 5),
#  ('interest', 4),
#  ('could', 3),
#  ('cryptocurrency', 3),
#  ('crypto', 3)]

# %%
# Use token_count to get the top 10 words for Ethereum
eth_text = ' '.join(eth_df.text)
eth_processed = clean_text(eth_text)
token_count(eth_processed)
# Out:
# [('char', 20),
#  ('ha', 9),
#  ('cryptocurrency', 8),
#  ('ethereum', 6),
#  ('wa', 5),
#  ('last', 4),
#  ('digital', 4),
#  ('eth', 4),
#  ('labs', 3),
#  ('bored', 3)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
btc_text_2 = ' '.join(btc_processed)

wc = WordCloud().generate(btc_text_2)
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
eth_text_2 = ' '.join(eth_processed)

wc = WordCloud().generate(eth_text_2)
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
btc_text = ' '.join(btc_df.text)

# %%
# Run the NER processor on all of the text
btc_doc = nlp(btc_text)

# Add a title to the document
btc_doc.user_data["title"] = "Bitcoin NER"

btc_doc
# Out:
# <ul><li>Elon Musk will be able to focus on Tesla (TSLA
# ) profits now that hes not taking a spot on Twitters (TWTR
# ) board.</li><li>Apple (AAPL
# ) could see $20 billion in sales this year from the i… [+4914 chars] Apparently not satisfied to report that it had mined over 5,700 Bitcoin( BTC -0.74% ) units in 2021 and more than 2,000 in the first two months of 2022, Core Scientific( CORZ -5.03% ) told the market… [+3620 chars] Financial markets are in a rough patch, as the triple threat of inflation, rising interest rates, and geopolitical uncertainty send investors racing to the exits. The cryptocurrency market, down 22% … [+2934 chars] Bitcoin's ( BTC 0.37% ) monumental run through 2020 and 2021 created a whole new macro asset class and industry. It's the type of thing that movies will be made about one day. But is it possible that… [+3700 chars] What happened
# Shares of Riot Blockchain(RIOT -6.62%) fell 52.1% in April 2022, according to data from S&amp;P Global Market Intelligence. This crash erased the 23% gains Riot posted in March, and th… [+2573 chars] What happened
# The cryptocurrency market had another bad end to the week on Friday, selling off into what could be a wild weekend. Yuga Labs will be minting some form of land for its metaverse and t… [+2413 chars] Robinhood has finally rolled out crypto wallets to the eligible customers on its waitlist, the trading platform said at Thursday's Bitcoin conference.
# Almost 2 million customers on Robinhood's WenWa… [+1478 chars] Bitcoin
#  BTC
#  and cryptocurrency prices have been stuck in a holding pattern ahead of the Federal Reserve's closely-watched Wednesday interest rate decision that could come with a $9 trillion bomb… [+3776 chars] On April 27, The Central African Republic's parliament voted unanimously to make Bitcoin(BTC 2.76%) legal tender. Unless you are familiar with your geography or keep up with politics in central Afric… [+3273 chars] Cryptocurrencies were mixed on Tuesday, indicating uncertainty among traders ahead of the U.S. Federal Reserve's interest rate decision tomorrow.
# The Fed is expected to hike rates by 50 basis points… [+6201 chars] When I started investing in Bitcoin( BTC -0.09% ), I had the preconception that I must also learn to trade. It took me three years to learn that this is not the case. Not only am I not a trader, but … [+3283 chars] The S&amp;P 500 has not had a great 2022 so far, as the broad index is down 11% through the end of April. Soaring inflation, the Fed's plans to keep raising interest rates, and geopolitical turmoil h… [+3453 chars] SAN DIEGO, April 14, 2022 (GLOBE NEWSWIRE) -- California-based craft superfood chain everbowl (www.everbowl.com) once again demonstrates its innovative, and technologically progressive approach to bu… [+2186 chars] By Analytics Team, Giottus Crypto ExchangeBitcoin (BTC)s vicissitudes played out yet again as its price is now around $40,450, down from the intra-week high of $43,400. The coin, after having success… [+5281 chars] Good morning. Heres whats happening:
# Prices: Bitcoin dipped to a five-week low around $38,547 early Monday before bouncing back up above $40,000 later in the day.
# Insights: The size of the main swi… [+5816 chars] OMAHA, NEBRASKA - MAY 5: (FILE PHOTO) Warren Buffett (L) and Berkshire-Hathaway partner Charlie ... [+] Munger address members of the press May 5, 2002 in Omaha, Nebraska. The Schwarzenegger for Gove… [+8059 chars] Good morning, and welcome to First Mover, our daily newsletter putting the latest moves in crypto markets in context. Sign up here to get it in your inbox each weekday morning.
# Heres whats happening… [+5953 chars] <ul><li>Marathon Digital Holdings, one of the largest North American bitcoin-miners, released its production and mining operations update for April 2022. </li><li>Total bitcoin holdings equal 9,673 B… [+1791 chars] Key Insights:
# <ul><li>Terra (LUNA) tumbled by 12.0% on Saturday, following a Friday 6.1% slide.
# </li><li>This week, the Luna Foundation Guard (LFG) purchased an additional $1.5bn in bitcoin, which … [+3855 chars] <ul><li>Bitfarms, a publicly traded bitcoin mining company, released bitcoin production results and a mining operations update for April 2022. </li><li>The total revenue reached 405 BTC for the month… [+2646 chars]

# %%
# Render the visualization
displacy.render(btc_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">&lt;ul&gt;&lt;li&gt;Elon Musk will be able to focus on Tesla (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TSLA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>) profits now that hes not taking a spot on Twitters (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TWTR
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>) board.&lt;/li&gt;&lt;li&gt;Apple (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AAPL
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>) could see
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $20 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  in sales
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     this year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  from the i… [+4914 chars] Apparently not satisfied to report that it had mined over
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5,700
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin( BTC -0.74%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ) units in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than 2,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the first two months of 2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Core Scientific
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ( CORZ
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     -5.03%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  ) told the market… [+3620 chars] Financial markets are in a rough patch, as the triple threat of inflation, rising interest rates, and geopolitical uncertainty send investors racing to the exits. The cryptocurrency market, down
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     22%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  … [+2934 chars] Bitcoin's ( BTC
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.37%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  ) monumental run through
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  created a whole new macro asset class and industry. It's the type of thing that movies will be made
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     about one day
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>Shares of Riot Blockchain(RIOT -6.62%) fell
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     52.1%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , according to data from S&amp;amp;P
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Global Market Intelligence
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . This crash erased the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     23%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  gains
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Riot
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  posted in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>The cryptocurrency ma

# %%
# List all Entities
text = []
label = []
for ent in btc_doc.ents:
    text.append(ent.text)
    label.append(ent.label_)
    
data = {"Text": text, "Label": label}

btc_entity = pd.DataFrame(data)
btc_entity
# Out:
#                     Text     Label
# 0                   TSLA       ORG
# 1                   TWTR       ORG
# 2                   AAPL       ORG
# 3            $20 billion     MONEY
# 4              this year      DATE
# ..                   ...       ...
# 89                   LFG       ORG
# 90  an additional $1.5bn     MONEY
# 91            April 2022      DATE
# 92                   405  CARDINAL
# 93             the month      DATE
#
# [94 rows x 2 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
eth_text = ' '.join(eth_df.text)

# %%
# Run the NER processor on all of the text
eth_doc = nlp(eth_text)

# Add a title to the document
eth_doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(eth_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">A multi-billion dollar cryptocurrency company has apologised to users after its sale of metaverse land sparked a frenzy that temporarily brought down the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yuga Labs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the comp… [+3475 chars] When
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bored Ape Yacht Club
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  creators
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Yuga Labs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  announced its
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Otherside
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  NFT collection would launch on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 30
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , it was predicted by many to be the biggest
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  launch ever. Otherside is an upcoming Bore… [+6669 chars] If you ever wanted to buy an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  based on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , you would have to pay a transaction fee to register it on the blockchain.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Last week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>So you might ha… [+7216 chars]
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Digital
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  transformation is disrupting global businesses. The legal industry must consider digital technologies to keep changing tech trends. Blockchain-based smart contracts are
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  example of such te… [+8816 chars]
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mike Masnick
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  wrote a good piece on this topic on his Techdirt blog
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last week
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     First
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# , lets look at the world without any content moderation. A website that has no cont… [+3109 chars] We are excited to bring
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Transform
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  2022 back in-person
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July 19
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and virtually
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July 20 - 28
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Join AI and data leaders for insightful talks and exciting networking opportunities. Register
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# </br>For ove… [+6087 chars]
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The U.S. Treasury Department
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  has implicated the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     North Korea
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -backed
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lazarus Group
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (aka
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin:

# %%
# List all Entities

text = []
label = []
for ent in eth_doc.ents:
    text.append(ent.text)
    label.append(ent.label_)
    
data = {"Text": text, "Label": label}

eth_entity = pd.DataFrame(data)
eth_entity
# Out:
#                     Text    Label
# 0               Ethereum      ORG
# 1              Yuga Labs   PERSON
# 2   Bored Ape Yacht Club   PERSON
# 3              Yuga Labs   PERSON
# 4              Otherside      ORG
# ..                   ...      ...
# 66                  2014     DATE
# 67       Vitalik Buterin   PERSON
# 68              Ethereum      ORG
# 69                 0.95%  PERCENT
# 70              Ethereum      GPE
#
# [71 rows x 2 columns]

# %% [markdown]
# ---
